# %%
class employee:
    def __init__(self):
        self.name = "John"
        self.id = 101
        self.salary = 50000
        print('hello')

    def travel(self,destination):
        print(f'emoloyee is now travelling to {destination}')
        print('hello')

# %%
sam = employee()
# Out:
# hello

# %%
sam.name
# Out:
# 'John'

# %%
# printing the attribute
print(sam.name)
print(sam.id)
print(sam.salary)
# Out:
# John
# 101
# 50000

# %%
# calling a method
sam.travel('kerala')
# Out:
# emoloyee is now travelling to kerala
# hello
